# %% [markdown]
# # Suche Magnetfeld für optimale Korrektur mittels CMA-ES

# %%
import numpy as np
import matplotlib.pyplot as plt
import datetime as dt
import cma
from STEP import STEP

# %%
ebins = np.array([  0.98 ,   2.144,   2.336,   2.544,   2.784,   3.04 ,   3.312,
         3.6  ,   3.92 ,   4.288,   4.672,   5.088,   5.568,   6.08 ,
         6.624,   7.2  ,   7.84 ,   8.576,   9.344,  10.176,  11.136,
        12.16 ,  13.248,  14.4  ,  15.68 ,  17.152,  18.688,  20.352,
        22.272,  24.32 ,  26.496,  28.8  ,  31.36 ,  34.304,  37.376,
        40.704,  44.544,  48.64 ,  52.992,  57.6  ,  62.72 ,  68.608,
        74.752,  81.408,  89.088,  97.28 , 105.984, 115.2  , 125.44 ,
       137.216, 149.504, 162.816, 178.176, 194.56 , 211.968, 230.4  ,
       372.736])

def grenz(t):
    return -0.5*t + 20

# dat = STEP(2021, 12, 4, rpath='data/STEP/', mag_path='data/mag/srf', mag_frame = 'srf')
dat = STEP(2021,12,4,mag_path='default',mag_frame='srf')
period =(dt.datetime(2021,12,4,13,50),dt.datetime(2021,12,4,14,30))
# Out:
# STEP-Data loaded successfully.
# STEP-Data combined successfully.
# 2021-12-04 00:00:00 /data/projects/solo/mag/l2_soar/srf/2021/solo_L2_mag-srf-normal_20211204_V01.cdf

# %%
def pw(flow,B,B_offset):
    '''Übergebe den particle flow-Vektor als Geschwindigkeit und den Magnetfeldvektor (am besten in SRF) und berechne die Pitchwinkel über das Skalarprodukt.
    Zusätzlich kann für die Magnetfeldkomponenten ein konstanter Offset übergeben werden.'''
    len_flow = np.sqrt(flow[0]**2 + flow[1]**2 + flow[2]**2)
    len_B = np.sqrt((B[0]+B_offset[0])**2 + (B[1]+B_offset[1])**2 + (B[2]+B_offset[2])**2)
    argument = (flow[0]*(B[0]+B_offset[0]) + flow[1]*(B[1]+B_offset[1]) + flow[2]*(B[2]+B_offset[2]))/len_flow/len_B
    result = np.arccos(argument)
    return result
        
def calc_pw(dat,B_offset):
    '''Berechne die Pitchwinkel für die Elektronen, welche auf STEP treffen in erster Näherung.
    Dafür wird der Winkel zwischen dem particle flow vector der Pixel und dem Magnetfeld herangezogen.
    Kann wieder einen Offset für das Magnetfeld übergeben.'''
    pws =  []
    for i in range(15):
        pws.append(pw(dat.flow_vector[i],[dat.B_R,dat.B_T,dat.B_N],B_offset))
    return np.array(pws)

def average_pw(dat,period,pitchangles,window_width=5):
    '''Berechnung der gemittelten Pitchwinkel'''
    # Maske, da ich nur die Magnetfelddaten innerhalb von period brauche:
    mask = (dat.time > period[0]) * (dat.time <= period[1])
    pw = [[] for i in range(15)]
    pw_time = []
        
    i = 0
    while (period[0] + dt.timedelta(minutes=(i+1)*window_width)) <= period[1]:
        pw_time.append(period[0] + dt.timedelta(minutes=(i+0.5)*window_width))
            
        for k in [i for i in range(1,16)]:
            # Mittelung der Pitchwinkel (k-1, da ich keine Zeit im array stehen habe)
            pw_data = pitchangles[k-1][mask]
            new_pw = np.sum(pw_data[i*window_width:(i+1)*window_width])/window_width
            pw[k-1].append(new_pw)
        i +=1
    return pw, pw_time

def step_plot_correction_multiple_offsets(dat, period, grenz, Offsets, title=None):
    '''Berechne und Plotte die Korrektur für manipulierte Magnetfelddaten und packe alles in einen Plot.'''

    pixel_means, pixel_var = dat.calc_energy_means(ebins=ebins,head=-1, period=period, grenzfunktion=grenz, norm='ptmax')
    
    # Offsets = np.array([np.zeros(11),np.zeros(11),np.array([i for i in range(-5,6)])]).T

    pixel1 = 3
    
    fig, ax = dat.step_plot('time', 'difference of energy means [keV]', f'difference of corrected energy means to pixel {pixel1}')

    for B_offset in Offsets:
        pitchangles = calc_pw(dat.mag,B_offset)
        pw, pw_time = average_pw(dat.mag,period,pitchangles)

        year = str(period[0].year - 2000)
        if period[0].month < 10:
            month = '0' + str(period[0].month)
        else:
            month = str(period[0].month)
        if period[0].day < 10:
            day = '0' + str(period[0].day)
        else:
            day = str(period[0].day)

        ax[0].plot([],[],label=str(B_offset))

        for pixel2 in range(1,16):
            # Übergebe willkürliche Fehler, da ich diese eh nicht brauche.
            energy2_corrected = dat.energy_correction(pixel_means[pixel2],pw[pixel1-1],pw[pixel2-1],2,2)[0]
            diff_corrected = energy2_corrected - pixel_means[pixel1]
            
            ax[pixel2].plot(pixel_means[0],diff_corrected,marker='x')
            ax[pixel2].axhline(0,color='tab:red')
                
            ax[pixel2].tick_params(axis='x',labelrotation=45)
    ax[0].legend()
    if type(title) == str:
        plt.savefig(f'mag_variation_cmaes/' + title + '.png')
    else:
        plt.savefig(f'mag_variation_cmaes/step_plot_total_correction_differences_energy_pixel{pixel1}_{year}_{month}_{day}_multiple_offsets.png')
    plt.close('all')

# %%
def func_to_min(B_offset,pixel_means,reference_pixel=3):
        '''Berechne für jeden Pixel den Mittelwert der Abweichungen aus allen Werten der Zeitreihe.
        Anschließend mittele ich über alle Pixel.'''
        deviation_of_pixels = []

        for pixel in range(1,16):
                pitchangles = calc_pw(dat.mag,B_offset)
                pw, pw_time = average_pw(dat.mag,period,pitchangles)

                energy2_corrected = dat.energy_correction(pixel_means[pixel],pw[reference_pixel-1],pw[pixel-1],2,2)[0]
                diff_corrected = energy2_corrected - pixel_means[reference_pixel]
                pixel_deviation = np.sum(diff_corrected)/len(diff_corrected)
                deviation_of_pixels.append(pixel_deviation)

        total_deviation = np.sum(np.array(deviation_of_pixels))/len(deviation_of_pixels)
        print('calculated function to minimize')
        return abs(total_deviation)

def func_to_min2(B_offset,pixel_means,reference_pixel=3):
        '''Berechne für jeden Pixel den Mittelwert der Abweichungen aus allen Werten der Zeitreihe.
        Anschließend mittele ich über alle Pixel.'''
        deviation_of_pixels = np.array([])

        for pixel in range(1,16):
                pitchangles = calc_pw(dat.mag,B_offset)
                pw, pw_time = average_pw(dat.mag,period,pitchangles)

                energy2_corrected = dat.energy_correction(pixel_means[pixel],pw[reference_pixel-1],pw[pixel-1],2,2)[0]
                diff_corrected = energy2_corrected - pixel_means[reference_pixel]
                deviation_of_pixels = np.concatenate((deviation_of_pixels,diff_corrected))

        total_deviation = np.sum(np.array(deviation_of_pixels))/len(deviation_of_pixels)
        print('calculated function to minimize')
        return abs(total_deviation)

# %%
pixel_means = dat.calc_energy_means(ebins=ebins,head=-1, period=period, grenzfunktion=grenz, norm='ptmax')[0]

# %%
B_offset0 = [0,0,0]

x_opt, es = cma.fmin2(objective_function = func_to_min2, x0 = [B_offset0], sigma0 = 0.5, args = [pixel_means], options = {'maxfevals':100})
print(x_opt)
# Out:
# c:\Users\ebel1\anaconda3\lib\site-packages\cma\utilities\utils.py:343: UserWarning: input x0 should be a list or 1-D array, trying to flatten (1, 3)-array ()
#   warnings.warn(msg + ' (' +
# (3_w,7)-aCMA-ES (mu_w=2.3,w_1=58%) in dimension 3 (seed=897942, Fri Sep 15 13:11:02 2023)
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      7 3.578349503817720e-02 1.0e+00 4.28e-01  4e-01  4e-01 1:03.7
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
#     2     14 2.385157695454521e-02 1.3e+00 5.60e-01  5e-01  7e-01 2:07.0
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
#     3     21 1.432495816795865e-02 1.7e+00 5.90e-01  5e-01  7e-01 3:15.3
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
#     4     28 9.007941501610552e-02 1.9e+00 4.66e-01  3e-01  6e-01 4:26.3
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
#     5     35 5.349016239259026e-02 2.1e+00 3.59e-01  3e-01  4e-01 5:29.5
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
#     6     42 1.761772710696400e-02 2.1e+00 3.04e-01  2e-01  3e-01 6:32.3
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
#     7     49 1.033026119444003e-03 2.4e+00 3.63e-01  2e-01  4e-01 7:36.8
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
#     8     56 3.017885917776771e-03 2.5e+00 5.44e-01  3e-01  6e-01 8:40.6
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
#     9     63 7.322858527304039e-02 3.2e+00 6.01e-01  3e-01  6e-01 9:44.9
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
#    10     70 1.342461863903720e-02 3.5e+00 6.08e-01  4e-01  7e-01 10:47.9
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
#    11     77 5.624768107541793e-03 4.1e+00 4.84e-01  3e-01  5e-01 11:50.3
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
#    12     84 1.138778422539233e-02 4.7e+00 4.44e-01  2e-01  5e-01 12:54.0
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
#    13     91 8.853263063872536e-04 5.8e+00 4.21e-01  2e-01  5e-01 13:57.8
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
#    14     98 2.432219110279104e-02 6.4e+00 4.21e-01  2e-01  5e-01 15:02.1
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
#    15    105 2.566143987989496e-03 7.9e+00 3.30e-01  2e-01  4e-01 16:06.1
# calculated function to minimize
# termination on maxfevals=100 (Fri Sep 15 13:27:17 2023)
# final/bestever f-value = 4.942150e-03 8.853263e-04 after 106/87 evaluations
# incumbent solution: [-1.1598118207096957, 0.26771628503645917, -1.2669826122156809]
# std deviation: [0.3994998164282894, 0.19171449257604734, 0.2988988485369194]
# [-1.46507209  0.41276429 -1.39693563]

# %%
es.result_pretty()
# Out:
# termination on maxfevals=100
# final/bestever f-value = 8.853263e-04 8.853263e-04 after 106/87 evaluations
# incumbent solution: [-1.1598118207096957, 0.26771628503645917, -1.2669826122156809]
# std deviation: [0.3994998164282894, 0.19171449257604734, 0.2988988485369194]
# CMAEvolutionStrategyResult(xbest=array([-1.46507209,  0.41276429, -1.39693563]), fbest=0.0008853263063872536, evals_best=87, evaluations=106, iterations=15, xfavorite=array([-1.15981182,  0.26771629, -1.26698261]), stds=array([0.39949982, 0.19171449, 0.29889885]), stop={'maxfevals': 100})

# %%
B_offset = x_opt
print(B_offset)

step_plot_correction_multiple_offsets(dat,period,grenz,[[0,0,0],B_offset],'mag_variation_cmaes_2021_12_04_second_try')
# Out:
# [-1.46507209  0.41276429 -1.39693563]

# %% [markdown]
# Versuche Pixel einzeln zu optimieren und den Magnetfeld-Offset für die geringste Abweichung zum Referenzpixe zu finden:

# %%
def func_to_min_single_pixel(B_offset,pixel_means,pixel,reference_pixel=3):
    '''Berechne Abstand der korrigierten Energie zum Referenzpixel für einen einzelnen Pixel.'''
    pitchangles = calc_pw(dat.mag,B_offset)
    pw, pw_time = average_pw(dat.mag,period,pitchangles)

    energy2_corrected = dat.energy_correction(pixel_means[pixel],pw[reference_pixel-1],pw[pixel-1],2,2)[0]
    diff_corrected = energy2_corrected - pixel_means[reference_pixel]
    pixel_deviation = np.sum(diff_corrected)/len(diff_corrected)
    print('calculated function to minimize')
    return abs(pixel_deviation)

# %%
B_offset0 = [0,0,0]
B_offsets_pixel = []
es_pixel = []

for pixel in range(1,16):
    x_opt, es = cma.fmin2(objective_function = func_to_min_single_pixel, x0 = [B_offset0], sigma0 = 0.5, args = [pixel_means,pixel], options = {'maxfevals':100})
    B_offsets_pixel.append(x_opt)
    es_pixel.append(es)

print('Idealer Magnetfeld-Offset:')
for pixel in range(1,16):
    print(f'Pixel {pixel}: {B_offsets_pixel[pixel-1]}')
# Out:
# (3_w,7)-aCMA-ES (mu_w=2.3,w_1=58%) in dimension 3 (seed=103078, Mon Sep 18 09:38:07 2023)
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      7 1.341813968027975e+00 1.0e+00 4.31e-01  4e-01  4e-01 0:02.7
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
#     2     14 6.653627835839511e-01 1.3e+00 4.34e-01  4e-01  4e-01 0:05.3
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
#     3     21 3.203058450522076e-01 1.3e+00 5.14e-01  4e-01  6e-01 0:08.0
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
#     5     35 3.807907034333091e-03 2.1e+00 5.81e-01  4e-01  8e-01 0:13.3
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
#     7     49 4.903792819213715e-03 2.6e+00 6.96e-01  4e-01  1e+00 0:18.7
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
#     9     63 1.394359888550059e-01 3.8e+00 6.01e-01  3e-01  1e+00 0:24.1
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
#    12     84 5.431820850663627e-02 5.7e+00 7.92e-01  3e-01  2e+00 0:32.2
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
#    15    105 1.092390520515485e-02 8.5e+00 6.08e-01  1e-01  1e+00 0:40.3
# calculated function to minimize
# termination on maxfevals=100 (Mon Sep 18 09:38:48 2023)
# final/bestever f-value = 5.916627e-03 3.807907e-03 after 106/34 evaluations
# incumbent solution: [-2.472920240120048, 0.9121422976507101, 0.9364667878373747]
# std deviation: [1.2146756459507404, 0.36186949758069104, 0.13259076688224203]
# (3_w,7)-aCMA-ES (mu_w=2.3,w_1=58%) in dimension 3 (seed=47951, Mon Sep 18 09:38:48 2023)
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      7 6.393414475038228e-02 1.0e+00 4.92e-01  5e-01  5e-01 0:02.6
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
#     2     14 2.745137863464113e-01 1.3e+00 3.94e-01  3e-01  4e-01 0:05.2
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
#     3     21 4.200517457482045e-02 1.3e+00 3.83e-01  3e-01  4e-01 0:07.9
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
#     5     35 1.785022546267623e-02 1.8e+00 3.88e-01  2e-01  4e-01 0:13.1
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
#     7     49 3.814075418513507e-02 2.8e+00 4.33e-01  2e-01  6e-01 0:18.4
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
#     9     63 5.504759891215660e-02 3.8e+00 3.47e-01  1e-01  4e-01 0:23.7
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
#    12     84 5.309342636336423e-03 6.3e+00 4.11e-01  1e-01  7e-01 0:31.7
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
#    15    105 2.085433819454252e-05 8.7e+00 3.53e-01  7e-02  6e-01 0:39.6
# calculated function to minimize
# termination on maxfevals=100 (Mon Sep 18 09:39:28 2023)
# final/bestever f-value = 2.488691e-03 2.085434e-05 after 106/103 evaluations
# incumbent solution: [-0.9151761375608762, 0.278209884411864, 0.48348046730701855]
# std deviation: [0.28249584724503257, 0.6440076846726008, 0.07069358582054873]
# (3_w,7)-aCMA-ES (mu_w=2.3,w_1=58%) in dimension 3 (seed=82512, Mon Sep 18 09:39:28 2023)
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      7 0.000000000000000e+00 1.0e+00 4.87e-01  5e-01  5e-01 0:02.6
# calculated function to minimize
# termination on tolfun=1e-11 (Mon Sep 18 09:39:31 2023)
# final/bestever f-value = 0.000000e+00 0.000000e+00 after 8/1 evaluations
# incumbent solution: [0.5426396828311231, -0.12820319099817015, 0.0420371109773872]
# std deviation: [0.4902001107562395, 0.4588282676625749, 0.4752602376235108]
# (3_w,7)-aCMA-ES (mu_w=2.3,w_1=58%) in dimension 3 (seed=103476, Mon Sep 18 09:39:31 2023)
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      7 5.149885998017740e-01 1.0e+00 4.10e-01  4e-01  4e-01 0:02.6
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
#     2     14 2.718031460907644e-01 1.3e+00 3.89e-01  3e-01  4e-01 0:05.3
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
#     3     21 1.699728328907302e-02 1.3e+00 4.59e-01  4e-01  5e-01 0:07.9
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
#     5     35 1.539998520870509e-01 1.6e+00 3.83e-01  3e-01  4e-01 0:13.2
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
#     7     49 6.692571085967547e-02 2.2e+00 3.83e-01  2e-01  4e-01 0:18.5
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
#     9     63 9.375886309076265e-03 3.1e+00 3.74e-01  3e-01  4e-01 0:23.7
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
#    12     84 2.861874728796843e-02 3.9e+00 1.97e-01  8e-02  2e-01 0:31.7
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
#    15    105 3.152959191491833e-03 5.1e+00 1.43e-01  6e-02  1e-01 0:39.6
# calculated function to minimize
# termination on maxfevals=100 (Mon Sep 18 09:40:11 2023)
# final/bestever f-value = 5.628083e-03 3.152959e-03 after 106/104 evaluations
# incumbent solution: [-0.3221539971342523, 0.23139810216435175, -0.8057370882238445]
# std deviation: [0.12143822308272503, 0.1070059999163608, 0.060110284916504324]
# (3_w,7)-aCMA-ES (mu_w=2.3,w_1=58%) in dimension 3 (seed=179484, Mon Sep 18 09:40:11 2023)
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      7 2.639033194892402e-01 1.0e+00 4.75e-01  5e-01  5e-01 0:02.6
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
#     2     14 4.548392955841574e-02 1.2e+00 4.11e-01  3e-01  4e-01 0:05.3
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
#     3     21 3.556759158558465e-02 1.4e+00 3.47e-01  2e-01  3e-01 0:07.9
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
#     5     35 1.018081196368581e-01 1.7e+00 2.40e-01  1e-01  2e-01 0:13.3
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
#     7     49 1.149658656711683e-04 2.2e+00 2.26e-01  8e-02  2e-01 0:18.6
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
#     9     63 3.997611888299235e-02 3.5e+00 1.72e-01  5e-02  2e-01 0:23.9
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
#    12     84 2.684434572321370e-03 4.8e+00 1.68e-01  3e-02  2e-01 0:31.8
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
#    15    105 1.980979114406312e-03 8.7e+00 1.20e-01  2e-02  1e-01 0:39.8
# calculated function to minimize
# termination on maxfevals=100 (Mon Sep 18 09:40:51 2023)
# final/bestever f-value = 4.336587e-04 1.149659e-04 after 106/46 evaluations
# incumbent solution: [-0.2697654181421031, 0.18303170105595085, 0.4430024077421509]
# std deviation: [0.0852353084100889, 0.1307155477892775, 0.015668291727018183]
# (3_w,7)-aCMA-ES (mu_w=2.3,w_1=58%) in dimension 3 (seed=176829, Mon Sep 18 09:40:51 2023)
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      7 3.278652533447108e-01 1.0e+00 5.53e-01  5e-01  6e-01 0:02.6
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
#     2     14 5.892915597125663e-01 1.5e+00 5.46e-01  4e-01  7e-01 0:05.3
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
#     3     21 2.410769695799910e-01 1.7e+00 5.58e-01  4e-01  7e-01 0:07.9
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
#     5     35 3.209901889383726e-02 2.7e+00 6.39e-01  4e-01  1e+00 0:13.2
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
#     7     49 1.460501754928445e-02 3.7e+00 6.61e-01  3e-01  1e+00 0:18.5
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
#     9     63 2.350517159337924e-01 6.4e+00 1.04e+00  5e-01  2e+00 0:23.8
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
#    12     84 3.463097937381665e-02 1.2e+01 1.04e+00  5e-01  2e+00 0:31.9
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
#    15    105 2.682458763818807e-02 2.1e+01 9.97e-01  4e-01  3e+00 0:40.2
# calculated function to minimize
# termination on maxfevals=100 (Mon Sep 18 09:41:32 2023)
# final/bestever f-value = 1.587537e-02 1.460502e-02 after 106/48 evaluations
# incumbent solution: [-9.376904219161492, 2.7900986878564535, -1.041441726430532]
# std deviation: [2.7192717664915715, 0.8991295423043697, 0.4269068647128726]
# (3_w,7)-aCMA-ES (mu_w=2.3,w_1=58%) in dimension 3 (seed=119134, Mon Sep 18 09:41:32 2023)
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      7 1.134721657870372e-01 1.0e+00 4.43e-01  4e-01  5e-01 0:02.7
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
#     2     14 1.105762339478444e-01 1.2e+00 3.70e-01  3e-01  4e-01 0:05.3
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
#     3     21 1.158775377656074e-02 1.5e+00 4.19e-01  3e-01  5e-01 0:07.9
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
#     5     35 5.394901607043368e-02 2.6e+00 3.18e-01  2e-01  4e-01 0:13.2
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
#     7     49 2.080274267313786e-02 3.1e+00 2.96e-01  2e-01  3e-01 0:18.5
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
#     9     63 4.843757574149121e-03 5.3e+00 2.60e-01  2e-01  3e-01 0:23.8
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
#    12     84 2.412584171572196e-02 6.1e+00 2.41e-01  2e-01  3e-01 0:31.7
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
#    15    105 2.183517514751321e-03 7.3e+00 1.82e-01  1e-01  2e-01 0:39.6
# calculated function to minimize
# termination on maxfevals=100 (Mon Sep 18 09:42:12 2023)
# final/bestever f-value = 2.718661e-03 1.983877e-03 after 106/71 evaluations
# incumbent solution: [0.03190813806535338, 0.16491089274148937, 0.09442310192188466]
# std deviation: [0.18119868312623355, 0.1274332478334345, 0.1127380815498653]
# (3_w,7)-aCMA-ES (mu_w=2.3,w_1=58%) in dimension 3 (seed=154853, Mon Sep 18 09:42:12 2023)
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      7 1.076989998895594e+00 1.0e+00 5.37e-01  5e-01  6e-01 0:02.6
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
#     2     14 5.186751555477023e-01 1.4e+00 7.06e-01  7e-01  8e-01 0:05.3
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
#     3     21 3.521196403059412e-02 1.7e+00 8.41e-01  8e-01  1e+00 0:07.9
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
#     5     35 1.437749164927693e-01 1.9e+00 7.77e-01  7e-01  1e+00 0:13.2
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
#     7     49 2.018301693545992e-01 1.9e+00 7.03e-01  6e-01  7e-01 0:18.4
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
#     9     63 1.985892329832142e-01 1.7e+00 9.91e-01  6e-01  1e+00 0:23.6
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
#    12     84 9.517130516721295e-02 2.4e+00 1.05e+00  5e-01  1e+00 0:31.4
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
#    15    105 5.402006615532429e-02 3.5e+00 7.09e-01  2e-01  8e-01 0:39.3
# calculated function to minimize
# termination on maxfevals=100 (Mon Sep 18 09:42:52 2023)
# final/bestever f-value = 5.616960e-02 1.650505e-02 after 106/95 evaluations
# incumbent solution: [-1.6771922183400703, -1.8415174312046008, 1.126145867369519]
# std deviation: [0.6193548506457497, 0.2232022595523417, 0.7632565018402211]
# (3_w,7)-aCMA-ES (mu_w=2.3,w_1=58%) in dimension 3 (seed=149729, Mon Sep 18 09:42:52 2023)
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      7 6.613540205285482e-01 1.0e+00 4.80e-01  4e-01  5e-01 0:02.7
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
#     2     14 7.344562649348751e-02 1.3e+00 6.00e-01  5e-01  8e-01 0:05.3
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
#     3     21 3.079869702549287e-01 1.9e+00 5.44e-01  5e-01  7e-01 0:08.0
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
#     5     35 6.747716162580608e-02 2.1e+00 4.56e-01  4e-01  5e-01 0:13.4
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
#     7     49 1.233094268377291e-01 2.2e+00 3.58e-01  2e-01  4e-01 0:18.8
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
#     9     63 1.409158913804132e-02 2.3e+00 4.81e-01  3e-01  5e-01 0:24.2
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
#    12     84 9.494879312494708e-03 3.2e+00 5.12e-01  3e-01  6e-01 0:32.2
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
#    15    105 3.341584206553172e-03 5.3e+00 4.03e-01  2e-01  5e-01 0:40.1
# calculated function to minimize
# termination on maxfevals=100 (Mon Sep 18 09:43:33 2023)
# final/bestever f-value = 1.640315e-03 1.640315e-03 after 106/106 evaluations
# incumbent solution: [-2.2756349112706107, 0.40976705835864147, 0.9829207805912541]
# std deviation: [0.48777942399050495, 0.3730337829457875, 0.20508158886588795]
# (3_w,7)-aCMA-ES (mu_w=2.3,w_1=58%) in dimension 3 (seed=93557, Mon Sep 18 09:43:33 2023)
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      7 2.060656214222096e-01 1.0e+00 4.60e-01  4e-01  5e-01 0:02.6
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
#     2     14 1.655547803895774e-01 1.3e+00 4.80e-01  4e-01  5e-01 0:05.3
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
#     3     21 1.415504993573613e-02 1.7e+00 4.17e-01  3e-01  5e-01 0:07.9
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
#     5     35 1.660654107386783e-02 2.2e+00 3.74e-01  2e-01  4e-01 0:13.3
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
#     7     49 6.160702747468827e-03 2.7e+00 3.85e-01  2e-01  5e-01 0:18.6
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
#     9     63 5.401781779452053e-03 4.6e+00 2.97e-01  1e-01  4e-01 0:23.8
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
#    12     84 9.061265596248602e-02 1.1e+01 5.25e-01  3e-01  1e+00 0:31.7
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
#    15    105 2.160427779115737e-02 1.4e+01 5.70e-01  2e-01  9e-01 0:39.7
# calculated function to minimize
# termination on maxfevals=100 (Mon Sep 18 09:44:13 2023)
# final/bestever f-value = 1.835797e-02 5.225231e-03 after 106/91 evaluations
# incumbent solution: [-0.8964416246112934, -0.013966572692917623, 0.16449244798743076]
# std deviation: [0.6330400015025, 0.8959587491413294, 0.22713917349469606]
# (3_w,7)-aCMA-ES (mu_w=2.3,w_1=58%) in dimension 3 (seed=160464, Mon Sep 18 09:44:13 2023)
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      7 2.109028701839961e-01 1.0e+00 4.56e-01  4e-01  4e-01 0:02.6
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
#     2     14 2.321206761409123e-03 1.3e+00 4.29e-01  4e-01  4e-01 0:05.3
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
#     3     21 3.738200586626683e-02 1.5e+00 3.52e-01  3e-01  4e-01 0:07.9
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
#     5     35 8.506088704998271e-02 2.2e+00 4.32e-01  4e-01  5e-01 0:13.2
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
#     7     49 1.074585417607639e-01 3.7e+00 4.05e-01  3e-01  5e-01 0:18.5
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
#     9     63 1.256876015060964e-01 3.8e+00 3.59e-01  3e-01  4e-01 0:23.8
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
#    12     84 1.497685123130599e-02 6.9e+00 1.91e-01  2e-01  2e-01 0:31.8
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
#    15    105 8.450345459519726e-03 1.5e+01 1.59e-01  1e-01  2e-01 0:39.7
# calculated function to minimize
# termination on maxfevals=100 (Mon Sep 18 09:44:53 2023)
# final/bestever f-value = 3.773591e-03 2.321207e-03 after 106/12 evaluations
# incumbent solution: [-0.5148219367346739, -0.23284464563292437, 0.7921457519640623]
# std deviation: [0.1588741276231835, 0.1970328313563845, 0.14136174733372558]
# (3_w,7)-aCMA-ES (mu_w=2.3,w_1=58%) in dimension 3 (seed=138289, Mon Sep 18 09:44:53 2023)
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      7 8.992103998216769e-01 1.0e+00 4.86e-01  4e-01  5e-01 0:02.6
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
#     2     14 1.366803769312226e-01 1.3e+00 5.46e-01  4e-01  6e-01 0:05.3
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
#     3     21 7.597188433520108e-02 1.5e+00 5.40e-01  4e-01  6e-01 0:07.9
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
#     5     35 1.361581678675667e-01 1.4e+00 5.55e-01  4e-01  7e-01 0:13.1
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
#     7     49 1.258850801477938e-01 2.3e+00 4.01e-01  3e-01  5e-01 0:18.4
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
#     9     63 5.240557796549949e-02 2.8e+00 2.90e-01  2e-01  3e-01 0:23.7
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
#    12     84 2.444925402332765e-02 4.7e+00 2.43e-01  1e-01  4e-01 0:31.6
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
#    15    105 1.613713620915647e-02 8.4e+00 3.49e-01  2e-01  6e-01 0:39.5
# calculated function to minimize
# termination on maxfevals=100 (Mon Sep 18 09:45:33 2023)
# final/bestever f-value = 1.443717e-04 1.443717e-04 after 106/106 evaluations
# incumbent solution: [0.2018539202350418, 1.4820070636089864, -0.36982938651118413]
# std deviation: [0.5731620575078422, 0.31205712780274647, 0.20264011725961814]
# (3_w,7)-aCMA-ES (mu_w=2.3,w_1=58%) in dimension 3 (seed=125891, Mon Sep 18 09:45:33 2023)
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      7 6.979060889829363e-01 1.0e+00 4.59e-01  4e-01  5e-01 0:02.6
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
#     2     14 1.925229833129694e-01 1.3e+00 5.13e-01  5e-01  5e-01 0:05.3
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
#     3     21 3.097048340709563e-03 1.2e+00 5.26e-01  5e-01  6e-01 0:07.9
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
#     5     35 2.197354454567340e-01 1.7e+00 5.35e-01  3e-01  6e-01 0:13.2
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
#     7     49 6.491827599069344e-02 2.3e+00 3.76e-01  2e-01  4e-01 0:18.5
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
#     9     63 1.307736171689799e-02 3.4e+00 4.48e-01  2e-01  6e-01 0:23.8
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
#    12     84 6.375830441449937e-02 7.4e+00 4.32e-01  2e-01  6e-01 0:31.7
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
#    15    105 3.840179720981474e-02 7.7e+00 4.92e-01  3e-01  8e-01 0:39.6
# calculated function to minimize
# termination on maxfevals=100 (Mon Sep 18 09:46:13 2023)
# final/bestever f-value = 4.602772e-02 3.097048e-03 after 106/17 evaluations
# incumbent solution: [-1.6498111304540903, -0.3672379713715406, 1.5792001270319451]
# std deviation: [0.7882308540247841, 0.25041903066746807, 0.6099772593540437]
# (3_w,7)-aCMA-ES (mu_w=2.3,w_1=58%) in dimension 3 (seed=166896, Mon Sep 18 09:46:13 2023)
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      7 2.428626782926120e-01 1.0e+00 6.09e-01  5e-01  8e-01 0:02.6
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
#     2     14 9.558266755466494e-02 1.7e+00 6.04e-01  5e-01  8e-01 0:05.3
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
#     3     21 6.964443564583922e-03 1.7e+00 5.32e-01  4e-01  6e-01 0:07.9
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
#     5     35 5.635236520011633e-03 2.6e+00 6.21e-01  5e-01  8e-01 0:13.2
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
#     7     49 2.263195231986597e-01 4.0e+00 7.95e-01  7e-01  1e+00 0:18.5
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
#     9     63 2.762963585931710e-02 5.7e+00 1.10e+00  1e+00  2e+00 0:23.7
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
#    12     84 3.187451128748120e-02 1.1e+01 7.84e-01  7e-01  1e+00 0:31.5
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
#    15    105 7.425601214546362e-02 1.3e+01 6.79e-01  7e-01  1e+00 0:39.4
# calculated function to minimize
# termination on maxfevals=100 (Mon Sep 18 09:46:53 2023)
# final/bestever f-value = 7.513008e-02 5.635237e-03 after 106/31 evaluations
# incumbent solution: [-2.3081372745731144, -1.5841521514291643, -2.241240495596204]
# std deviation: [0.7583756550550357, 0.6511582566671911, 1.1160574410305117]
# (3_w,7)-aCMA-ES (mu_w=2.3,w_1=58%) in dimension 3 (seed=136023, Mon Sep 18 09:46:53 2023)
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      7 2.490626978499000e-01 1.0e+00 4.36e-01  4e-01  4e-01 0:02.7
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
#     2     14 1.624303127508253e-02 1.2e+00 4.09e-01  3e-01  4e-01 0:05.4
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
#     3     21 1.021194833629957e-01 1.3e+00 3.34e-01  2e-01  3e-01 0:08.0
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
#     5     35 3.398749963682524e-02 1.5e+00 2.26e-01  1e-01  2e-01 0:13.4
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
#     7     49 2.425771572438018e-02 1.7e+00 2.13e-01  1e-01  2e-01 0:18.7
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
#     9     63 5.496793896182295e-02 2.5e+00 2.05e-01  1e-01  2e-01 0:24.0
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
#    12     84 4.730712476045174e-03 4.0e+00 1.29e-01  8e-02  9e-02 0:32.0
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
# calculated function to minimize
#    15    105 1.429744987652515e-02 5.4e+00 9.56e-02  5e-02  7e-02 0:39.9
# calculated function to minimize
# termination on maxfevals=100 (Mon Sep 18 09:47:34 2023)
# final/bestever f-value = 1.498792e-02 4.401724e-04 after 106/89 evaluations
# incumbent solution: [0.06426988108478918, 0.11509318230967176, 0.566825791660397]
# std deviation: [0.06962949345101564, 0.06068739865530234, 0.05080971692670433]
# Idealer Magnetfeld-Offset:
# Pixel 1: [-1.00700475  0.20036712  0.98893686]
# Pixel 2: [-1.03716605  0.17185106  0.47397226]
# Pixel 3: [ 0.75852399 -0.23038888 -0.19591474]
# Pixel 4: [-0.34556409  0.22702699 -0.80919081]
# Pixel 5: [-0.2877091   0.31527151  0.4333491 ]
# Pixel 6: [-0.85421679  0.77469092 -0.16761913]
# Pixel 7: [-0.14341238  0.25364945  0.06307313]
# Pixel 8: [-1.70596198 -1.74338468  2.03401098]
# Pixel 9: [-2.27563491  0.40976706  0.98292078]
# Pixel 10: [-1.23713686  0.76077277  0.30063697]
# Pixel 11: [ 0.32574609  0.70995621 -0.10996794]
# Pixel 12: [ 0.20185392  1.48200706 -0.36982939]
# Pixel 13: [-0.43621236 -0.77333513  0.59556648]
# Pixel 14: [-0.32782692 -0.51684426  0.44123577]
# Pixel 15: [0.12511957 0.11958061 0.60503415]

# %%
def step_plot_different_offsets_each_pixel(dat, period, grenz, Offsets, title=None):
    '''Übergebe für jedem Pixel einen eigenen Magnetfeld-Offset, um ideale Korrektur zu erreichen.'''

    pixel_means, pixel_var = dat.calc_energy_means(ebins=ebins,head=-1, period=period, grenzfunktion=grenz, norm='ptmax')
    
    # Offsets = np.array([np.zeros(11),np.zeros(11),np.array([i for i in range(-5,6)])]).T

    pixel1 = 3
    
    fig, ax = dat.step_plot('time', 'difference of energy means [keV]', f'difference of corrected energy means to pixel {pixel1}')

    year = str(period[0].year - 2000)
    if period[0].month < 10:
         month = '0' + str(period[0].month)
    else:
        month = str(period[0].month)
    if period[0].day < 10:
        day = '0' + str(period[0].day)
    else:
        day = str(period[0].day)

    for pixel2 in range(1,16):
        pitchangles = calc_pw(dat.mag,Offsets[pixel2-1])
        pw, pw_time = average_pw(dat.mag,period,pitchangles)
            
        # Übergebe willkürliche Fehler, da ich diese eh nicht brauche.
        energy2_corrected = dat.energy_correction(pixel_means[pixel2],pw[pixel1-1],pw[pixel2-1],2,2)[0]
        diff_corrected = energy2_corrected - pixel_means[pixel1]
            
        ax[pixel2].plot(pixel_means[0],diff_corrected,marker='x',label=f'{Offsets[pixel2-1]}')
        ax[pixel2].axhline(0,color='tab:red')
                
        ax[pixel2].tick_params(axis='x',labelrotation=45)
        ax[pixel2].legend()
    if type(title) == str:
        plt.savefig(f'mag_variation_cmaes/' + title + '.png')
    else:
        plt.savefig(f'mag_variation_cmaes/step_plot_total_correction_differences_energy_pixel{pixel1}_{year}_{month}_{day}_multiple_offsets.png')
    plt.close('all')

# %%
step_plot_different_offsets_each_pixel(dat, period, grenz, B_offsets_pixel, title='optimal_correction_each_pixel')

# %% [markdown]
# Berechne ideales Magnetfeld für jeden Zeitpunkt meiner Zeitreihe (mit externem Skript):

# %%
def step_plot_ideal_offsets_each_ts(dat, period, grenz, Offsets_ts, title=None):
    '''Übergebe Zeitreihe von idealen Magnetfeld-Offsets, um damit ideale Korrektur zu berechnen.'''

    pixel_means, pixel_var = dat.calc_energy_means(ebins=ebins,head=-1, period=period, grenzfunktion=grenz, norm='ptmax')
    
    len_ts = len(pixel_means[0])
    
    # Offsets = np.array([np.zeros(11),np.zeros(11),np.array([i for i in range(-5,6)])]).T

    pixel1 = 3
    
    fig, ax = dat.step_plot('time', 'difference of energy means [keV]', f'difference of corrected energy means to pixel {pixel1}')

    year = str(period[0].year - 2000)
    if period[0].month < 10:
         month = '0' + str(period[0].month)
    else:
        month = str(period[0].month)
    if period[0].day < 10:
        day = '0' + str(period[0].day)
    else:
        day = str(period[0].day)

    for pixel2 in range(1,16):
        diff_of_pixel = []
        for pot in range(len_ts):
            # Gehen die folgenden zwei zeilen einfacher?
            pitchangles = calc_pw(dat.mag,Offsets_ts[pot])
            pw, pw_time = average_pw(dat.mag,period,pitchangles)
            
            # Übergebe willkürliche Fehler, da ich diese eh nicht brauche.
            energy2_corrected = dat.energy_correction(pixel_means[pixel2][pot],pw[pixel1-1][pot],pw[pixel2-1][pot],2,2)[0]
            diff_corrected = energy2_corrected - pixel_means[pixel1][pot]
            diff_of_pixel.append(diff_corrected)
            
        ax[pixel2].plot(pixel_means[0],diff_of_pixels,marker='x')
        ax[pixel2].axhline(0,color='tab:red')
                
        ax[pixel2].tick_params(axis='x',labelrotation=45)
    if type(title) == str:
        plt.savefig(f'mag_variation_cmaes/' + title + '.png')
    else:
        plt.savefig(f'mag_variation_cmaes/step_plot_total_correction_differences_energy_pixel{pixel1}_{year}_{month}_{day}_multiple_offsets.png')
    plt.close('all')

# %%
opt_b_ts = [array([-0.51750594,  1.0390966 ,  2.95802849]), array([ 0.75955021,  0.76883405, -0.10316687]), array([-1.51450692,  1.15373077, -2.02308867]), array([-3.50551777, -0.7891109 ,  4.23075418]), array([-1.88151883, -0.62277722, -2.11933347]), array([-0.21840517, -1.58434976,  0.57044087]), array([-0.27608079, -1.5068718 ,  0.43600885]), array([ 0.16117981, -1.36556997,  0.77313155])]

step_plot_ideal_offsets_each_ts(dat, period, grenz, opt_b_ts, title='ideal_mag_offsets_ts_2021_12_04)
